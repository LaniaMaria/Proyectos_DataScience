# %%
import pandas as pd

# %%
df = pd.read_csv("https://raw.githubusercontent.com/ywchiu/riii/master/data/house-prices.csv")

# %%
df
# Out:
#      Home   Price  SqFt  Bedrooms  Bathrooms  Offers Brick Neighborhood
# 0       1  114300  1790         2          2       2    No         East
# 1       2  114200  2030         4          2       3    No         East
# 2       3  114800  1740         3          2       1    No         East
# 3       4   94700  1980         3          2       3    No         East
# 4       5  119800  2130         3          3       3    No         East
# ..    ...     ...   ...       ...        ...     ...   ...          ...
# 123   124  119700  1900         3          3       3   Yes         East
# 124   125  147900  2160         4          3       3   Yes         East
# 125   126  113500  2070         2          2       2    No        North
# 126   127  149900  2020         3          3       1    No         West
# 127   128  124600  2250         3          3       4    No        North
#
# [128 rows x 8 columns]

# %%
#Visualisación

# %%
df.plot()
# Out:
# <AxesSubplot:>

# %%
#x linea horizontal, y linea vertical
#kind es el nombre del parametro de la funcción
df.plot(kind = "scatter", x = "SqFt", y = "Price")
# Out:
# <AxesSubplot:xlabel='SqFt', ylabel='Price'>

# %%
df.plot(kind = "box")
# Out:
# <AxesSubplot:>

# %%
df.Price.plot(kind = "box")
# Out:
# <AxesSubplot:>

# %%
df.plot.box(column = "Price", by = "Neighborhood")
# Out:
# Price    AxesSubplot(0.125,0.125;0.775x0.755)
# dtype: object

# %%
df.Price.plot.kde()
# Out:
# <AxesSubplot:ylabel='Density'>

# %%
df.SqFt.plot.kde()
# Out:
# <AxesSubplot:ylabel='Density'>

# %%
df.Price.plot.hist()
# Out:
# <AxesSubplot:ylabel='Frequency'>

# %%
df.SqFt.plot.hist(bins = 30)
# Out:
# <AxesSubplot:ylabel='Frequency'>

# %%
df.head()
# Out:
#    Home   Price  SqFt  Bedrooms  Bathrooms  Offers Brick Neighborhood
# 0     1  114300  1790         2          2       2    No         East
# 1     2  114200  2030         4          2       3    No         East
# 2     3  114800  1740         3          2       1    No         East
# 3     4   94700  1980         3          2       3    No         East
# 4     5  119800  2130         3          3       3    No         East

# %%
df.Neighborhood.value_counts()
# Out:
# East     45
# North    44
# West     39
# Name: Neighborhood, dtype: int64

# %%
df.Neighborhood.value_counts().plot.bar()
# Out:
# <AxesSubplot:>

# %%
df.Brick.value_counts().plot.bar()
# Out:
# <AxesSubplot:>

# %%
df.Brick.value_counts().plot.pie()
# Out:
# <AxesSubplot:ylabel='Brick'>

# %%
#Graficas con seaborn

# %%
import seaborn as sns

# %%
sns.pairplot(df)

# %%
sns.pairplot(df, hue = "Neighborhood")
